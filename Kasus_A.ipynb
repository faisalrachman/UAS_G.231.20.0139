# %%
#Import required libraries 
import keras #library for neural network
import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library

# %%
#Reading data 
data=pd.read_csv("Dataset/iris.csv")
print("Describing the data: ",data.describe())
print("Info of the data:",data.info())
# Out:
# Describing the data:         sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# Info of the data: None

# %%
print("10 first samples of the dataset:",data.head(10))
print("10 last samples of the dataset:",data.tail(10))
# Out:
# 10 first samples of the dataset:    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
# 10 last samples of the dataset:      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
sns.lmplot('sepal_length', 'sepal_width',
           data=data,
           fit_reg=False,
           hue="species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('SepalLength vs SepalWidth')

sns.lmplot('petal_length', 'petal_width',
           data=data,
           fit_reg=False,
           hue="species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('PetalLength vs PetalWidth')

sns.lmplot('sepal_length', 'sepal_width',
           data=data,
           fit_reg=False,
           hue="species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('SepalLength vs PetalLength')

sns.lmplot('petal_length', 'petal_width',
           data=data,
           fit_reg=False,
           hue="species",
           scatter_kws={"marker": "D",
                        "s": 50})
plt.title('SepalWidth vs PetalWidth')
plt.show()
# Out:
# c:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(data["species"].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
data.loc[data["species"]=="Iris-setosa","species"]=0
data.loc[data["species"]=="Iris-versicolor","species"]=1
data.loc[data["species"]=="Iris-virginica","species"]=2
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
data=data.iloc[np.random.permutation(len(data))]
print(data.head())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 35            5.0          3.2           1.2          0.2       0
# 100           6.3          3.3           6.0          2.5       2
# 43            5.0          3.5           1.6          0.6       0
# 13            4.3          3.0           1.1          0.1       0
# 57            4.9          2.4           3.3          1.0       1

# %%
X=data.iloc[:,0:4].values
y=data.iloc[:,4].values

print("Shape of X",X.shape)
print("Shape of y",y.shape)
print("Examples of X\n",X[:3])
print("Examples of y\n",y[:3])
# Out:
# Shape of X (150, 4)
# Shape of y (150,)
# Examples of X
#  [[5.  3.2 1.2 0.2]
#  [6.3 3.3 6.  2.5]
#  [5.  3.5 1.6 0.6]]
# Examples of y
#  [0 2 0]

# %%
X_normalized=normalize(X,axis=0)
print("Examples of X_normalised\n",X_normalized[:3])
# Out:
# Examples of X_normalised
#  [[0.06917906 0.08470916 0.02361125 0.01150299]
#  [0.08716562 0.08735632 0.11805627 0.14378743]
#  [0.06917906 0.09265065 0.03148167 0.03450898]]

# %%
#Creating train,test and validation data
'''
80% -- train data
20% -- test data
'''
total_length=len(data)
train_length=int(0.65*total_length)
test_length=int(0.35*total_length)

X_train=X_normalized[:train_length]
X_test=X_normalized[train_length:]
y_train=y[:train_length]
y_test=y[train_length:]

print("Length of train set x:",X_train.shape[0],"y:",y_train.shape[0])
print("Length of test set x:",X_test.shape[0],"y:",y_test.shape[0])
# Out:
# Length of train set x: 97 y: 97
# Length of test set x: 53 y: 53

# %%
#Neural network module
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
from tensorflow.keras.layers import BatchNormalization 
from keras.utils import np_utils

# %%
#Change the label to one hot vector
'''
[0]--->[1 0 0]
[1]--->[0 1 0]
[2]--->[0 0 1]
'''
y_train=np_utils.to_categorical(y_train,num_classes=3)
y_test=np_utils.to_categorical(y_test,num_classes=3)
print("Shape of y_train",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of y_train (97, 3)
# Shape of y_test (53, 3)

# %%
model=Sequential()
model.add(Dense(1000,input_dim=4,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1000)              5000
#
#  dense_5 (Dense)             (None, 16)                16016
#
#  dense_6 (Dense)             (None, 16)                272
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 21,339
# Trainable params: 21,339
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=100,epochs=20,verbose=1)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 636ms/step - loss: 0.2029 - accuracy: 0.9381 - val_loss: 0.1373 - val_accuracy: 0.9623
# Epoch 2/20
# 1/1 [==============================] - 0s 91ms/step - loss: 0.2507 - accuracy: 0.8969 - val_loss: 0.1370 - val_accuracy: 0.9623
# Epoch 3/20
# 1/1 [==============================] - 0s 86ms/step - loss: 0.2116 - accuracy: 0.9381 - val_loss: 0.1362 - val_accuracy: 0.9623
# Epoch 4/20
# 1/1 [==============================] - 0s 171ms/step - loss: 0.2379 - accuracy: 0.9175 - val_loss: 0.1353 - val_accuracy: 0.9623
# Epoch 5/20
# 1/1 [==============================] - 0s 108ms/step - loss: 0.2278 - accuracy: 0.8969 - val_loss: 0.1345 - val_accuracy: 0.9623
# Epoch 6/20
# 1/1 [==============================] - 0s 128ms/step - loss: 0.2118 - accuracy: 0.9278 - val_loss: 0.1341 - val_accuracy: 0.9623
# Epoch 7/20
# 1/1 [==============================] - 0s 98ms/step - loss: 0.2133 - accuracy: 0.9278 - val_loss: 0.1342 - val_accuracy: 0.9623
# Epoch 8/20
# 1/1 [==============================] - 0s 96ms/step - loss: 0.2366 - accuracy: 0.9072 - val_loss: 0.1342 - val_accuracy: 0.9811
# Epoch 9/20
# 1/1 [==============================] - 0s 125ms/step - loss: 0.2189 - accuracy: 0.9381 - val_loss: 0.1344 - val_accuracy: 0.9811
# Epoch 10/20
# 1/1 [==============================] - 0s 123ms/step - loss: 0.2084 - accuracy: 0.8866 - val_loss: 0.1343 - val_accuracy: 0.9811
# Epoch 11/20
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1942 - accuracy: 0.9588 - val_loss: 0.1337 - val_accuracy: 0.9811
# Epoch 12/20
# 1/1 [==============================] - 0s 101ms/step - loss: 0.2244 - accuracy: 0.9691 - val_loss: 0.1332 - val_accuracy: 0.9811
# Epoch 13/20
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1872 - accuracy: 0.9588 - val_loss: 0.1326 - val_accuracy: 0.9811
# Epoch 14/20
# 1/1 [==============================] - 0s 101ms/step - loss: 0.2428 - accuracy: 0.9175 - val_loss: 0.1321 - val_accuracy: 0.9811
# Epoch 15/20
# 1/1 [==============================] - 0s 111ms/step - loss: 0.2020 - accuracy: 0.9485 - val_loss: 0.1313 - val_accuracy: 0.9811
# Epoch 16/20
# 1/1 [==============================] - 0s 123ms/step - loss: 0.2336 - accuracy: 0.9072 - val_loss: 0.1304 - val_accuracy: 0.9811
# Epoch 17/20
# 1/1 [==============================] - 0s 193ms/step - loss: 0.2242 - accuracy: 0.9485 - val_loss: 0.1294 - val_accuracy: 0.9811
# Epoch 18/20
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2225 - accuracy: 0.9381 - val_loss: 0.1285 - val_accuracy: 0.9811
# Epoch 19/20
# 1/1 [==============================] - 0s 104ms/step - loss: 0.2285 - accuracy: 0.8866 - val_loss: 0.1276 - val_accuracy: 0.9623
# Epoch 20/20
# 1/1 [==============================] - 0s 114ms/step - loss: 0.1959 - accuracy: 0.9485 - val_loss: 0.1269 - val_accuracy: 0.9623

# %%
prediction=model.predict(X_test)
length=len(prediction)
y_label=np.argmax(y_test,axis=1)
predict_label=np.argmax(prediction,axis=1)

accuracy=np.sum(y_label==predict_label)/length * 100 
print("Accuracy of the dataset",accuracy )
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Accuracy of the dataset 96.22641509433963

# %%
from sklearn.metrics import classification_report, confusion_matrix
predictions = np.argmax(model.predict(X_test), axis = 1)
Y_test = np.argmax(y_test, axis =1)
print(confusion_matrix(Y_test, predictions))
print(classification_report(Y_test, predictions))
# Out:
# 2/2 [==============================] - 0s 6ms/step
# [[21  0  0]
#  [ 0 18  1]
#  [ 0  1 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        21
#            1       0.95      0.95      0.95        19
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        53
#    macro avg       0.96      0.96      0.96        53
# weighted avg       0.96      0.96      0.96        53
